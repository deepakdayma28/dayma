# %%
import pandas as pd

# %%
house=pd.read_excel("house price predic6ion dataset.xlsx")

# %%
house
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0         Owner                   0     0        2       BHK  1300.236407
# 1        Dealer                   0     0        2       BHK  1275.000000
# 2         Owner                   0     0        2       BHK   933.159722
# 3         Owner                   0     1        2       BHK   929.921143
# 4        Dealer                   1     0        2       BHK   999.009247
# ...         ...                 ...   ...      ...       ...          ...
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# ...

# %%
house.head()
# Out:
#   POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 0     Owner                   0     0        2       BHK  1300.236407
# 1    Dealer                   0     0        2       BHK  1275.000000
# 2     Owner                   0     0        2       BHK   933.159722
# 3     Owner                   0     1        2       BHK   929.921143
# 4    Dealer                   1     0        2       BHK   999.009247
#
#    READY_TO_MOVE  RESALE                      ADDRESS  LONGITUDE  LONGITUDE.1  \
# 0              1       1        Ksfc Layout,Bangalore  12.969910    13.969910
# 1              1       1    Vishweshwara Nagar,Mysore  12.274538    13.274538
# 2              1       1             Jigani,Bangalore  12.778033    13.778033
# 3              1       1  Sector-1 Vaishali,Ghaziabad  28.642300    29.642300
# 4              0       1             New Town,Kolkata  22.592200    23.592200
#
#    TARGET PRICE
# 0          55.0
# 1          51.0
# 2          43.0
# ...

# %%
house.tail()
# Out:
#       POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO. BHK_OR_RK    SQUARE_FT  \
# 29446     Owner                   0     0        3       BHK  2500.000000
# 29447     Owner                   0     0        2       BHK   769.230769
# 29448    Dealer                   0     0        2       BHK  1022.641509
# 29449     Owner                   0     0        2       BHK   927.079009
# 29450    Dealer                   0     1        2       BHK   896.774194
#
#        READY_TO_MOVE  RESALE                            ADDRESS  LONGITUDE  \
# 29446              1       1               Shamshabad Road,Agra  27.140626
# 29447              1       1  E3-108, Lake View Recidency,,Vapi  39.945409
# 29448              1       1                  Ajmer Road,Jaipur  26.928785
# 29449              1       1             Sholinganallur,Chennai  12.900150
# 29450              1       1                   Jagatpura,Jaipur  26.832353
#
#        LONGITUDE.1  TARGET PRICE
# 29446    28.140626          45.0
# ...

# %%
house.shape
# Out:
# (29451, 12)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
POSTED_BY=LabelEncoder()
UNDER_CONSTRUCTION=LabelEncoder()
RERA=LabelEncoder()
BHK_NO=LabelEncoder()
BHK_OR_RK=LabelEncoder()
SQUARE_FT=LabelEncoder()
READY_TO_MOVE=LabelEncoder()
RESALE=LabelEncoder()
ADDRESS=LabelEncoder()
LONGITUDE=LabelEncoder()
LONGITUDE1=LabelEncoder()
TARGETPRICE=LabelEncoder()

# %%
house["POSTED_BY"]=POSTED_BY.fit_transform(house["POSTED_BY"])
house["UNDER_CONSTRUCTION"]=POSTED_BY.fit_transform(house["UNDER_CONSTRUCTION"])
house["RERA"]=POSTED_BY.fit_transform(house["RERA"])
house["BHK_NO."]=POSTED_BY.fit_transform(house["BHK_NO."])
house["BHK_OR_RK"]=POSTED_BY.fit_transform(house["BHK_OR_RK"])
house["SQUARE_FT"]=POSTED_BY.fit_transform(house["SQUARE_FT"])
house["READY_TO_MOVE"]=POSTED_BY.fit_transform(house["READY_TO_MOVE"])
house["RESALE"]=POSTED_BY.fit_transform(house["RESALE"])
house["ADDRESS"]=POSTED_BY.fit_transform(house["ADDRESS"])
house["LONGITUDE"]=POSTED_BY.fit_transform(house["LONGITUDE"])
house["LONGITUDE.1"]=POSTED_BY.fit_transform(house["LONGITUDE.1"])
house["TARGET PRICE"]=POSTED_BY.fit_transform(house["TARGET PRICE"])

# %%
features_cols=["POSTED_BY","UNDER_CONSTRUCTION","RERA","BHK_NO.","BHK_OR_RK","SQUARE_FT","READY_TO_MOVE","RESALE","ADDRESS","LONGITUDE","LONGITUDE.1"]

# %%
x=house[features_cols]

# %%
x
# Out:
#        POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK  SQUARE_FT  \
# 0              2                   0     0        1          0      11182
# 1              1                   0     0        1          0      10756
# 2              2                   0     0        1          0       5422
# 3              2                   0     1        1          0       5360
# 4              1                   1     0        1          0       6376
# ...          ...                 ...   ...      ...        ...        ...
# 29446          2                   0     0        2          0      18164
# 29447          2                   0     0        1          0       3546
# 29448          1                   0     0        1          0       6683
# 29449          2                   0     0        1          0       5323
# 29450          1                   0     1        1          0       4849
#
#        READY_TO_MOVE  RESALE  ADDRESS  LONGITUDE  LONGITUDE.1
# ...

# %%
y=TARGETPRICE

# %%
y
# Out:
# LabelEncoder()

# %% [markdown]
# # train_test_split

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(house[["POSTED_BY","UNDER_CONSTRUCTION","RERA","BHK_NO.","BHK_OR_RK","SQUARE_FT","READY_TO_MOVE","RESALE","ADDRESS","LONGITUDE","LONGITUDE.1"]],house["TARGET PRICE"],test_size=0.3)

# %%
x_train
# Out:
#        POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK  SQUARE_FT  \
# 19327          1                   0     0        2          0       7404
# 14870          2                   0     0        2          0      14806
# 317            2                   0     0        1          0       3812
# 17788          2                   0     0        2          0      13659
# 21941          1                   1     1        3          0      14340
# ...          ...                 ...   ...      ...        ...        ...
# 16080          1                   0     0        2          0      12070
# 14221          1                   0     0        2          0      13768
# 17133          1                   1     0        1          0       8355
# 20614          1                   1     1        0          0        592
# 2059           1                   1     1        2          0      16042
#
#        READY_TO_MOVE  RESALE  ADDRESS  LONGITUDE  LONGITUDE.1
# ...

# %%
y_train
# Out:
# 19327    163
# 14870    792
# 317      290
# 17788    879
# 21941    931
#         ...
# 16080    792
# 14221    693
# 17133    383
# 20614    399
# 2059     645
# Name: TARGET PRICE, Length: 20615, dtype: int64

# %%
x_test
# Out:
#        POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK  SQUARE_FT  \
# 18026          2                   0     1        1          0       9268
# 2341           1                   0     0        1          0       5062
# 809            2                   0     0        1          0       4807
# 11281          2                   0     0        2          0      16538
# 3944           1                   0     0        1          0       6642
# ...          ...                 ...   ...      ...        ...        ...
# 2313           2                   0     0        2          0      12031
# 15106          1                   1     1        1          0       6652
# 4716           1                   0     0        2          0      15541
# 12963          1                   0     0        1          0       5578
# 14956          1                   0     0        1          0       4694
#
#        READY_TO_MOVE  RESALE  ADDRESS  LONGITUDE  LONGITUDE.1
# ...

# %%
y_test
# Out:
# 18026    426
# 2341     221
# 809      544
# 11281    935
# 3944     280
#         ...
# 2313     372
# 15106    703
# 4716     838
# 12963    238
# 14956    270
# Name: TARGET PRICE, Length: 8836, dtype: int64

# %% [markdown]
# # LogisticRegression use for prediction

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\dayma\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array([930, 188, 394, ..., 930, 188, 188], dtype=int64)

# %%
x_test
# Out:
#        POSTED_BY  UNDER_CONSTRUCTION  RERA  BHK_NO.  BHK_OR_RK  SQUARE_FT  \
# 18026          2                   0     1        1          0       9268
# 2341           1                   0     0        1          0       5062
# 809            2                   0     0        1          0       4807
# 11281          2                   0     0        2          0      16538
# 3944           1                   0     0        1          0       6642
# ...          ...                 ...   ...      ...        ...        ...
# 2313           2                   0     0        2          0      12031
# 15106          1                   1     1        1          0       6652
# 4716           1                   0     0        2          0      15541
# 12963          1                   0     0        1          0       5578
# 14956          1                   0     0        1          0       4694
#
#        READY_TO_MOVE  RESALE  ADDRESS  LONGITUDE  LONGITUDE.1
# ...

# %%
lr.score(x_test,y_test)
# Out:
# 0.028632865550022635
